# %%
from langchain_groq import ChatGroq
from langchain.chains import ConversationChain
from langchain.chains.conversation.memory import ConversationBufferWindowMemory
from langchain.prompts import PromptTemplate
import os
from dotenv import load_dotenv
load_dotenv()
groq = ChatGroq(api_key=os.getenv('GROQ_API_KEY'),model="llama-3.1-8b-instant")
model = ConversationChain(
    llm=groq,  
    memory=ConversationBufferWindowMemory(k=5),
)
model.run("What is the capital of France?")
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_22400\2883514986.py:11: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory=ConversationBufferWindowMemory(k=5),
# C:\Users\mahes\AppData\Local\Temp\ipykernel_22400\2883514986.py:9: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :class:`~langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   model = ConversationChain(
# C:\Users\mahes\AppData\Local\Temp\ipykernel_22400\2883514986.py:13: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   model.run("What is the capital of France?")
# "Bonjour! The capital of France is Paris, of course. It's the largest city in France, both in terms of population and land area, with over 2.1 million residents. Paris has been the capital of France since 987, when Hugh Capet, the Count of Paris, was crowned King of the Franks. Did you know that the city's iconic Notre Dame Cathedral, which was built in the 12th century, is one of the most famous landmarks in the world and attracts millions of visitors each year?"

# %%
#map,reduce,filter,lambda
ls = [1,2,3,4,5]
tuple(filter(lambda x: x%2==0, ls))
# Out:
# (2, 4)
